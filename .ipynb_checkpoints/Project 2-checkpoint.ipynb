# %%
import pandas as pd
import numpy as np
import pickle
import xgboost as xgb
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("recipe_train.csv")

# %% [markdown]
# ## Preprocess

# %% [markdown]
# Creating dataset

# %%
heading_name = []
heading_steps = []
heading_ingr = []
for i in range(100):
    heading_name.append("name"+str(i))
    heading_steps.append("steps"+str(i))
    heading_ingr.append("ingr"+str(i))

heading_name_50 = heading_name[:50]
heading_steps_50 = heading_steps[:50]
heading_ingr_50 = heading_ingr[:50]

recipe_train = pd.read_csv('recipe_train.csv')
n_steps = recipe_train['n_steps']
n_ingr = recipe_train['n_ingredients']
duration_label = recipe_train['duration_label']

name_100 = pd.read_csv('recipe_text_features_doc2vec100/train_name_doc2vec100.csv', names=heading_name)
steps_100 = pd.read_csv('recipe_text_features_doc2vec100/train_steps_doc2vec100.csv', names=heading_steps)
ingr_100 = pd.read_csv('recipe_text_features_doc2vec100/train_ingr_doc2vec100.csv', names=heading_ingr)

name_50 = pd.read_csv('recipe_text_features_doc2vec50/train_name_doc2vec50.csv', names=heading_name_50)
steps_50 = pd.read_csv('recipe_text_features_doc2vec50/train_steps_doc2vec50.csv', names=heading_steps_50)
ingr_50 = pd.read_csv('recipe_text_features_doc2vec50/train_ingr_doc2vec50.csv', names=heading_ingr_50)

data_100 = name_100.join(steps_100).join(ingr_100).join(n_steps).join(n_ingr)
data_50 = name_50.join(steps_50).join(ingr_50).join(n_steps).join(n_ingr)

# %%
data_50
# Out:
#           name0     name1     name2     name3     name4     name5     name6  \
# 0     -0.040233  0.076782  0.249360 -0.181925  0.248722 -0.588148  0.535760
# 1     -0.171015  0.076204  0.016986 -0.208875 -0.241924 -0.235768  0.214952
# 2     -0.004516  0.002639  0.045212  0.064354 -0.295956 -0.030037 -0.125290
# 3      0.398416 -0.289314  0.120874 -0.109078  0.172739 -0.329223 -0.174549
# 4     -0.024000  0.188942 -0.060302  0.114219 -0.021253  0.168473 -0.003027
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.215868  0.233168 -0.006542 -0.326691 -0.154234  0.046174  0.119195
# 39996 -0.094745  0.129695  0.064144 -0.113078 -0.185521 -0.018393  0.161694
# 39997 -0.306564  0.022663 -0.074049  0.026526 -0.115985 -0.108808 -0.028160
# 39998  0.103624  0.226626 -0.132034 -0.124793  0.229029 -0.065741  0.069570
# 39999 -0.030284  0.218631 -0.038716  0.104782  0.187953 -0.575098  0.117146
#
#           name7     name8     name9  ...    ingr42    ingr43    ingr44  \
# 0     -0.060977 -0.376367  0.119354  ...  0.410408  0.196359 -0.422395
# 1     -0.229491 -0.083370  0.026395  ...  0.276983  0.164212 -0.082383
# 2      0.060692 -0.252764 -0.117760  ... -0.019909 -0.104222  0.068053
# 3      0.240794 -0.020434 -0.149348  ... -0.040816 -0.095826  0.253930
# 4      0.020890 -0.256069  0.276312  ...  0.130013 -0.115817  0.203033
# ...         ...       ...       ...  ...       ...       ...       ...
# 39995 -0.040960  0.271929  0.129032  ... -0.035639 -0.027201  0.211015
# 39996  0.130748 -0.224510  0.123720  ...  0.005364 -0.176063 -0.212104
# 39997  0.134257 -0.169984 -0.043473  ...  0.598130 -0.388287  0.034709
# 39998  0.210206  0.003720  0.013455  ...  0.091380 -0.266209  0.198064
# 39999  0.328395 -0.154484  0.525169  ...  0.061095 -0.180771  0.554879
#
#          ingr45    ingr46    ingr47    ingr48    ingr49  n_steps  \
# 0      0.140098  0.222497  0.257018  0.092791  0.090195        6
# 1     -0.367911 -0.049660 -0.249535 -0.330310  0.286444        9
# 2      0.208893 -0.100972 -0.016045  0.208270  0.192634       15
# 3     -0.500503  0.204917 -0.244062 -0.078134 -0.125225       10
# 4      0.105802  0.081311 -0.351688 -0.188493  0.065571        6
# ...         ...       ...       ...       ...       ...      ...
# 39995 -0.119868  0.425386 -0.373303  0.118591 -0.091006        6
# 39996  0.026536 -0.120713  0.212625  0.183138  0.487163       15
# 39997  0.215435 -0.111346 -0.300238  0.089310  0.098816        5
# 39998 -0.152284 -0.246992 -0.116655 -0.174231  0.242111        7
# 39999  0.049715  0.282064 -0.419384 -0.257240 -0.044911        6
#
#        n_ingredients
# 0                 12
# 1                  5
# 2                 10
# 3                  8
# 4                  5
# ...              ...
# 39995             13
# 39996             16
# 39997              8
# 39998             17
# 39999             11
#
# [40000 rows x 152 columns]

# %%
cross_val_score(SVC(gamma='auto'), data, duration_label,cv=3)
# Out:
# array([0.72018899, 0.72076802, 0.72706818])
