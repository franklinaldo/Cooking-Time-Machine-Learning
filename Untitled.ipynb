# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = ['500','750','1000', '5000', '10000']
s = [0.79575,0.798125,0.793875,0.790875,0.7895]

fig, ax = plt.subplots()

ax.plot(t, s)

ax.set(xlabel='k', ylabel='Accuracy',
       title='Logistic Regression Accuracy \nvs Number of K-best using Chi-square\n')
ax.grid()

fig.savefig("test.png")
plt.show()
